# %%
import pandas as pd
import matplotlib.pyplot as plt
import shutil, os, random, gc, time, traceback
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from keras import backend as K

from keras.applications import InceptionV3, VGG16, ResNet50, InceptionResNetV2, DenseNet201

from keras.models import Sequential, Model, load_model
from keras.layers import Dense, Conv2D, Flatten, Activation, Dropout, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, GlobalMaxPooling2D
from keras.losses import binary_crossentropy, categorical_crossentropy

import cache_magic
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
pd.options.display.float_format = "{:,.2f}".format

DATA_PATH = os.path.abspath(os.path.join(os.getcwd(), os.pardir, 'data')).replace('\\', '/') + '/'
MODEL_PATH = os.path.abspath(os.path.join(os.getcwd(), os.pardir, 'model_coarse')).replace('\\', '/') + '/'
BEST_MODEL = os.path.abspath(os.path.join(os.getcwd(), os.pardir, 'model','VGG16_data_imbalance.h5')).replace('\\', '/') 

NUM_CLASSES = 1000
ATTR_TYPES = {'1':"Estampado",'2':"Tejido",'3':"Forma",'4':"Partes",'5':"Estilo"}

# %%
# Rutas a directorios de datos
ANNO_COARSE_PATH = DATA_PATH + 'anno_coarse'
TRAIN_PATH = ANNO_COARSE_PATH + '/train'
VALIDATION_PATH = ANNO_COARSE_PATH + '/val'
TEST_PATH = ANNO_COARSE_PATH + '/test'
AUGMENTED_DATA_PATH = ANNO_COARSE_PATH + '/augmented'
IMG = DATA_PATH + 'img'

# Rutas a ficheros de datos
ATTR_CLOTH_LIST_FILE = ANNO_COARSE_PATH + '/list_attr_cloth.txt'
ATTR_IMG_LIST_FILE = ANNO_COARSE_PATH + '/list_attr_img.txt'
PARTITION_FILE = ANNO_COARSE_PATH + '/list_eval_partition.txt'

TRAIN_FILE_PATH = ANNO_COARSE_PATH + "/train_attr.txt"

# %% [markdown]
# # 1. Código de pre-procesamiento y entrenamiento

# %% [markdown]
# A continuación se define el código necesario para el procesamiento de los ficheros de datos, así como para el entrenamiento de los modelos. El código, salvo pequeños cambios por la estructura de datos, es idéntico al empleado para la versión reducida del conjunto de datos por lo que se omite su descripción detallada.

# %% [markdown]
# ## 1.1 Pre-procesamiento de datos

# %%
def read_partition_files():
    data = {}
    data['train'] = []
    data['test'] = []
    data['val'] = []
    with open(PARTITION_FILE) as fp:
        fp.readline() # Ingorar numero de etiquetas
        fp.readline() # Ingorar numero de etiquetas
        for line in fp:
            fields = line.split()
            
            img_path = fields[0]
            img_path = DATA_PATH + img_path
            
            partition = fields[1]
            data[partition].append(img_path)
    return data

# %%
partition_images = read_partition_files()

# %%
# Lectura de la lista de atributos (fichero list_attr_cloth.txt)
def read_attr_cloth_list():
    column_to_attr_name = {}
    attr_type_to_columns = {}
    
    with open(ATTR_CLOTH_LIST_FILE) as fp: 
        fp.readline() # Ingorar numero de etiquetas
        fp.readline() # Ignorar cabecera
        column = 0
        for line in fp: 
            fields = line.split()
            attr = " ".join(fields[:-1])
            attr_type = fields[-1]
            column_to_attr_name[column] = attr
            if attr_type in attr_type_to_columns:
                attr_type_to_columns[attr_type].append(column)
            else:
                attr_type_to_columns[attr_type] = [column]
            column += 1
    return column_to_attr_name, attr_type_to_columns

# %%
# column_to_attr_name: Mapping número columna -> Nombre de atributo
# attr_type_to_columns: Mapping tipo de atributo - Lista de columnas de atributos de dicho tipo
column_to_attr_name, attr_type_to_columns = read_attr_cloth_list()           
# Listado con los nombre de los atributos
attributes = list(column_to_attr_name.values())

# %%
# Devuelve el listado de imágnes del fichero recibido como parámetro
def read_image_list(file_name):
    file_path = ANNO_COARSE_PATH + '/' + file_name + '.txt'
    with open(file_path) as fp:
        return [DATA_PATH + img.rstrip('\n') for img in fp]
    
# Devuelve el path de la partición a partir del nombre de la partición
def build_partition_data_path(partition):
    return ANNO_COARSE_PATH + '/' + partition

# Creación de la estructura de datos necesaria para los generadores de aumentación de datos
def create_data_structure(partition_images, force=False):
    for partition in ['test', 'train', 'val']:
        partition_data_path = build_partition_data_path(partition)
        
        # Forzar recarga
        if os.path.exists(partition_data_path) and force:
            shutil.rmtree(partition_data_path)
        
        if not os.path.exists(partition_data_path):
            os.mkdir(partition_data_path)
            # Carga del listado de imágenes
            image_list = partition_images[partition]
            # Copia
            for i, src in enumerate(image_list):
                dst_filename = src.replace('../data/img/', '')
                dst_filename = dst_filename.replace('/','')
                dst = partition_data_path + '/' + dst_filename
                shutil.copyfile(src, dst)

# %%
create_data_structure(partition_images, False)

# %% [markdown]
# ## 1.2 Aumentación de datos:

# %%
# Construcción del dataframe requerido para usar la función flow_from_dataframe
# En el caso de no pasarle attr_type, tiene en cuenta todos los atributos (empleado en la versión con un único modelo)
# En caso contrario, filtra los atributos pertenecientes al tipo pasado por parámetro. (empleado en la versión de un modelo por
# tipo de atributo)
def build_iterator_dataframe(partition, attr_type=None):
    partition_attribute_filepath = ANNO_COARSE_PATH + "/" + partition + "_attr.txt"
    names = []
    names.append('filename')
    names.extend(attributes)
    data = pd.read_csv(partition_attribute_filepath, sep = ' ', names = names, index_col=False)
    
    # Filtrado por tipo de atributo. Empleado para los clasificadores separados por tipo de atributo. 
    if attr_type is not None:
        columns = attr_type_to_columns[str(attr_type)]
        fst, lst = columns[0], columns[-1]+1
        data = data.iloc[:, fst:lst]
    
    return data

# Devuelve los nombres de los atributos pertenecientes al tipo de atributo pasado por parámetro
def get_attributes_for_attribute_type(attr_type):
    if attr_type is None:
        return attributes
    else:
        return [column_to_attr_name[c] for c in attr_type_to_columns[str(attr_type)]]
    
SEED = 1
BATCH_SIZE = 4


# Construcción del generador de datos de entrenamiento
def build_train_datagen(shear_range=0.025, zoom_range=0.025, rotation_range=2.5, fill_mode='nearest'):
    return ImageDataGenerator(
        rescale=1/255.0,
        shear_range=shear_range,
        zoom_range=zoom_range,
        rotation_range=rotation_range,
        fill_mode = fill_mode,
        horizontal_flip=True)

# Construcción de los generadores de datos de entrenamiento y validación
def build_generators(img_size, shear_range, zoom_range, rotation_range, fill_mode, attr_type = None):
        
    # Borrar los directorios con las imagenes generadas
    if os.path.exists(AUGMENTED_DATA_PATH):
        shutil.rmtree(AUGMENTED_DATA_PATH)
    os.mkdir(AUGMENTED_DATA_PATH)
    
    # Generator de entrenamiento
    train_datagen = build_train_datagen(shear_range, zoom_range, rotation_range, fill_mode)
    train_generator = train_datagen.flow_from_dataframe(
        dataframe = build_iterator_dataframe('train', attr_type),
        x_col="filename",
        y_col=get_attributes_for_attribute_type(attr_type),
        directory=TRAIN_PATH,
        target_size=(img_size,img_size),
        batch_size=BATCH_SIZE,
        class_mode='raw',
        color_mode='rgb',
        seed=SEED,
        save_to_dir=AUGMENTED_DATA_PATH
    )
    
    print(TRAIN_PATH)

    # Generator de validación
    validation_datagen = ImageDataGenerator(
         rescale=1./255
    )

    validation_generator = validation_datagen.flow_from_dataframe(
        dataframe=build_iterator_dataframe('val', attr_type),
        x_col="filename",
        y_col=get_attributes_for_attribute_type(attr_type),
        directory=VALIDATION_PATH,
        target_size=(img_size,img_size),
        #batch_size=BATCH_SIZE,
        class_mode='raw',
        color_mode='rgb',
        seed=SEED
    )
    
    return train_generator, validation_generator


# Construcción del generador de datos de test
def build_test_generator(img_size=224, attr_type = None):
        
    test_datagen = ImageDataGenerator(
         rescale=1./255
    )
    
    test_generator = test_datagen.flow_from_dataframe(
        dataframe=build_iterator_dataframe('test', attr_type),
        x_col="filename",
        y_col=get_attributes_for_attribute_type(attr_type),        
        directory=TEST_PATH,
        target_size=(img_size,img_size),
       # batch_size=BATCH_SIZE,
        class_mode=None,
        color_mode='rgb',
        seed=SEED,
        shuffle=False
    )
    
    return test_generator

# %% [markdown]
# ## 1.3 Automatización del entrenamiento

# %%
EARLY_STOPPING_PATIENCE = 8
LR_REDUCTION_PATIENCE = 4

# Conversión del tamaño de la imagen al shape esperado como input del modelo
def to_input_shape(img_size):
    return (img_size,img_size,3)

# Construcción del path donde se persiste el modelo
def to_model_path(model_name, model_id, attr_type = None):
    if not os.path.exists(MODEL_PATH):
        os.mkdir(MODEL_PATH)
    if attr_type is None:
        return '{}/{}_{}.h5'.format(MODEL_PATH, model_name, model_id)
    else:
        return '{}/{}_{}_{}.h5'.format(MODEL_PATH, model_name, model_id, attr_type)

# Construcción del nombre de la función de instanciación de un modelo
def to_build_function(model_name):
    return 'build_' + model_name

# Desactiva el entrenamiento del X% de capas iniciales. 
def freeze_layers(model, ratio=0.5):
    n_layers = len(model.layers)
    last_layer_to_freeze = int(n_layers*ratio)
    
    for layer in model.layers[:last_layer_to_freeze]:
        layer.trainable = False
    for layer in model.layers[last_layer_to_freeze:]:
        layer.trainable = True
    
    return model

def freeze_all_layers(model):
    for layer in model.layers:
        layer.trainable = False

def build_callbacks(model_name, model_id, store_model, attr_type):
    callbacks = []
    # Parar la ejecución si el loss no disminuye en 3 iteraciones
    early_stopping = EarlyStopping(monitor='val_loss', patience=EARLY_STOPPING_PATIENCE, verbose=1, min_delta=1e-4)
    callbacks.append(early_stopping)
    # Reducir el learning rate si el loss no disminuye en 3 iteraciones
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=LR_REDUCTION_PATIENCE, verbose=1, min_delta=1e-4)  
    callbacks.append(reduce_lr)
    # Guardar el modelo que más disminuye el loss en fichero
    if store_model:
        checkpoint = ModelCheckpoint(filepath = to_model_path(model_name, model_id, attr_type), 
                                     monitor='val_auc', verbose=1, save_best_only=True, mode='max')
        callbacks.append(checkpoint)
    return callbacks

# Entrenamiento, y todo el pre-procesamiento necesario. 
def train(model_name,
          model_id=None,
          max_epochs=1000, 
          img_size=224,
          shear_range=0.05, 
          zoom_range=0.150, 
          rotation_range=2.5, 
          fill_mode='constant',
          store_model=True,
          freeze_layers_ratio=None,
          loss_function=binary_crossentropy,
          attr_type=None,
          class_weight = None
         ):
    
    # Forzar limpieza y pasar el GC
    K.clear_session()
    #cuda.select_device(0)
    #cuda.close()
    gc.collect()
    
    # Instanciación del modelo. Todos los métodos siguen el patrón "build_xxx", donde xxx es esl nombre del modelo
    input_shape = to_input_shape(img_size)
    model = globals()[to_build_function(model_name)]()
    #model.summary()
    
    # COMPILE con run options para debug en caso de oom
    #run_opts = tf.compat.v1.RunOptions(report_tensor_allocations_upon_oom = True)
    # model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.compile(optimizer='adam', loss=loss_function, metrics=[tf.keras.metrics.AUC(name='auc'), 'accuracy'])
    
    # Instanciación de los generators de datos
    train_generator, validation_generator = build_generators(img_size, shear_range, 
                                                             zoom_range, rotation_range, fill_mode, attr_type)
    
    
    h = model.fit_generator(train_generator, validation_data=validation_generator, 
                            epochs=max_epochs, callbacks = build_callbacks(model_name, model_id, False, attr_type),
                            steps_per_epoch=5000,
                            validation_steps=1000
                           )
    # Segunda fase de training para entrenar el resto de las capas
    model = freeze_layers(model, freeze_layers_ratio)
    model.compile(optimizer='adam', loss=loss_function, metrics=[tf.keras.metrics.AUC(name='auc'), 'accuracy'])
    h = model.fit_generator(train_generator, validation_data=validation_generator, 
                            epochs=max_epochs, callbacks = build_callbacks(model_name, model_id, store_model, attr_type),
                            steps_per_epoch=5000,
                            validation_steps=1000,
                            class_weight=class_weight
                           )

    
    return (h.history['val_loss'], h.history['val_accuracy'], h.history['val_auc'])

# %% [markdown]
# ## 1.3 Automatización de la evaluación

# %%
KS =  [3,5,20]

# Calcula
## Número de veces que aparece un atributo en una predicción
## Número de veces en el que la predicción de un atributo se realiza de forma correcta
## Número de veces en el que la predicción de un atributo se realiza de forma incorrecta
def get_prediction_metrics(y_true_df, y_pred, k=6):
    
    # Inicialización de los vectores
    times_predicted = [0] * NUM_CLASSES
    ground_truth = [0] * NUM_CLASSES
    times_correctly_predicted = [0] * NUM_CLASSES
    times_incorrectly_predicted = [0] * NUM_CLASSES

    for index, row in y_true_df.iterrows():
        
        # Obtención de los verdaderos positivos
        true_possitives = np.where(row==1)
        for i in true_possitives[0]:
            ground_truth[i]+=1

        # Obtención de los k valores con mayor probabilidad
        predicted_k_values = np.argpartition(y_pred[index], -k)[-k:]
        for p in predicted_k_values:
            
            # Clasificación
            times_predicted[p]+=1
            if p in true_possitives[0]:
                times_correctly_predicted[p]+=1
            else:
                times_incorrectly_predicted[p]+=1
    return times_predicted, ground_truth, times_correctly_predicted, times_incorrectly_predicted

# Calcula recall, precision y f1 usando macro averaging
def compute_macro_average_metrics(times_predicted, ground_truth, tp, fp):
    m = {}
    recall_per_label = [a/max(1,b) for a,b in zip(tp,ground_truth)]
    precision_per_label = [a/max(1,b) for a,b in zip(tp,times_predicted)]
    m['recall'] =  sum(recall_per_label)/NUM_CLASSES
    m['precision'] = sum(precision_per_label)/NUM_CLASSES
    f1_per_label = [2 * (p * r) / max(1,(p + r)) for p,r in zip(precision_per_label, recall_per_label)]
    m['f1'] = sum(f1_per_label)/NUM_CLASSES
    return m

# Calcula recall, precision y f1 usando micro averaging
def compute_micro_average_metrics(times_predicted, ground_truth, tp, fp):
    m = {}
    m['recall'] = sum(tp)/sum(ground_truth)
    m['precision'] = sum(tp)/sum(times_predicted)
    m['f1'] = 2 * (m['precision'] * m['recall']) / max(1,(m['precision'] + m['recall']))
    return m

# Calcula recall, precision y f1 usando micro/macro averaging para las k etiquetas con mayor probabilidad
def compute_evaluation_results(y_true_df, y_pred):
    results = {}
    for k in KS:
        # Calculo métricas de clasificación
        times_predicted, ground_truth, tp, fp = get_prediction_metrics(y_true_df, y_pred, k)
        
        results_k = {}
        results[k] = results_k
        # Micro average
        results_k['micro'] = compute_micro_average_metrics(times_predicted, ground_truth, tp, fp)
        
        # Macro average
        results_k['macro'] = compute_macro_average_metrics(times_predicted, ground_truth, tp, fp)
    return results

# Evaluación de un modelo.     
def evaluate(model_name, model_id):
    # Forzar limpieza y pasar el GC
    K.clear_session()
    gc.collect()

    # Recuperar el modelo guardado
    model = load_model(to_model_path(model_name, model_id), compile = False)
    model.compile(optimizer='adam', loss=binary_crossentropy, metrics=[tf.keras.metrics.AUC(name='auc'), 'accuracy'])
    
    # Generator de datos de test
    test_generator = build_test_generator()
    
    # Predicción
    y_pred = model.predict_generator(test_generator, steps=None, max_queue_size=10, workers=1, use_multiprocessing=False, verbose=1) 

    # Carga de las etiquetas del conjunto de test
    partition_attribute_filepath = ANNO_COARSE_PATH + "/test_attr.txt"
    y_true_df = pd.read_csv(partition_attribute_filepath, sep = ' ', names = [str(i) for i in range(0,NUM_CLASSES)], index_col=False)
    
    # Calcula resultados en formato r[k][average type][metric] donde
    # k - numero de etiquetas con mayor probabilidad
    # average type - micro|macro
    # metric - precision|recall|f1
    results = compute_evaluation_results(y_true_df, y_pred)
        
    return (y_pred, results)

# %%
COLUMNS = ['recall.micro','precision.micro','f1.micro','recall.macro','precision.macro','f1.macro']

def build_result_df(result_list, k):
    rows = []
    names = []
    for model_results, model_name in result_list:
        row = []
        rows.append(row)
        names.append(model_name)
        for avg in ['micro', 'macro']:
            for metric in ['recall', 'precision', 'f1']:
                row.append(model_results[k][avg][metric])

    return pd.DataFrame(rows, columns=COLUMNS, index=names)

# %%
# Construcción de la tabla de resultados a partir de la lista de listas de valores predichos por un modelo sobre la partición de test
def build_results_table(y_pred):

    # Carga de las anotaciones reales de la partición de test
    partition_attribute_filepath = ANNO_COARSE_PATH + "/test_attr.txt"
    y_true_df = pd.read_csv(partition_attribute_filepath, sep = ' ', names = [str(i) for i in range(0,NUM_CLASSES)], index_col=False)

    # Columna de tipo de atributo
    attr_types = []
    for k, v in attr_type_to_columns.items():
        attr_types.extend([ATTR_TYPES[str(k)]] * len(v))

    # Columna de frecuencia de predicción, Verdaderos positivos y Falsos positivos
    times_predicted, ground_truth, times_correctly_predicted, times_incorrectly_predicted = get_prediction_metrics(y_true_df, y_pred)

    # Columnas de sensibilidad y precisión
    recall = [a/max(1,b) for a,b in zip(times_correctly_predicted, ground_truth)]
    precision = [a/max(1,b) for a,b in zip(times_correctly_predicted, times_predicted)]
    f1 = [2 * (p * r) / max(1,(p + r)) for p,r in zip(precision, recall)]

    # Creación de dataframe
    d = {'Atributo': attributes, 'Tipo': attr_types, 'Frecuencia real' : ground_truth, 
         'Frecuencia predicción' : times_predicted, 'TP': times_correctly_predicted, 'FP' : times_incorrectly_predicted, 
         'Recall' : recall, 'Precision' : precision, 'F1' : f1}
    return pd.DataFrame(data=d)


def build_results_table_by_attr_type(results):
    df = build_results_table(results).groupby('Tipo').mean()
    return df.drop(columns=['Frecuencia real', 'Frecuencia predicción', 'TP', 'FP'])

# %% [markdown]
# # 2. Modelo con un único clasificador

# %% [markdown]
# En este apartado se va a entrenar un modelo basado en un único clasificador para la clasificación de los atributos. Se emplea como base el clasificador con el que se ha obtenido los mejores resultados con el conjunto reducido de datos para beneficiarse del *transfer learning*. Recordemos que este modelo estaba entrenado a partir de la arquitectura VGG16.
#
# Para ello se importa el modelo y se reemplaza la capa de salida por una con 1000 neuronas. Se emplea *sigmoid* como función de activación en la capa de salida para que el clasificador sea multi-etiqueta.

# %%
def build_VGG16():
    loaded_model = load_model(BEST_MODEL, compile = False)
    output = Dense(NUM_CLASSES, activation='sigmoid', name='dense_2')(loaded_model.layers[-2].output)
    model = Model(inputs=loaded_model.input, outputs=output)
    
    return model

# %% [markdown]
# Entrenamos el modelo siguiendo los mismos pasos que se siguieron para entrenar el modelo original:
# 1. Se entrena primero las capas densas añadidas al final de la red
# 2. Se entrena el resto de la red, manteniendo fijos los pesos del 80% de capas iniciales. Este valor es con el que se obtuvo mejores resultados con el conjunto de datos reducido.

# %%
#%cache -r coarse_vgg16_res
# %cache coarse_vgg16_res = train('VGG16',model_id='coarse', freeze_layers_ratio=0.80)
# Out:
# Loading cached value for variable 'coarse_vgg16_res'. Time since caching: 9 days, 5:29:46.530070

# %% [markdown]
# Y lo evaluamos con la partición de test. Para la evaluación se emplea k=5, esto es, se calcula la precisión, exhaustividad y F1 en base a los 5 atributos con mayor probabilidad en el output del modelo.
#
# En este caso, al no existir un número fijo de atributos asociado a una observación, la métrica más robusta es la exhaustividad:
#
# **Precisión** = Verdaderos positivos / (Verdaderos positivos + Falsos positivos)
#
# **Exhaustividad** = Verdaderos positivos / (Verdaderos positivos + Falsos negativos)
#
# En este caso la precisión (y por tanto, también el F1) no es una métrica robusta puesto que existen observaciones asociadas a un número de atributos inferior a K. En esos casos, incluso en el caso de que todos los atributos se identifiquen de forma correcta, existirá un número de falsos positivos equivalente a la diferencia entre K y el número real de atributos positivos. La exhaustividad emplea en el denominador el *ground truth* y no depende del valor de K elegido.
#
# El valor elegido para K es 5 puesto que éste es el que se emplea en los *papers* del estado del arte para establecer una comparativa entre modelos.

# %%
#%cache -r vgg16_coarse_test_res
# %cache vgg16_coarse_test_res = evaluate('VGG16', model_id = 'coarse')
# Out:
# Loading cached value for variable 'vgg16_coarse_test_res'. Time since caching: 9 days, 5:21:21.831215

# %%
build_result_df([(vgg16_coarse_test_res[1], 'VGG16')], k=5)
# Out:
#        recall.micro  precision.micro  f1.micro  recall.macro  precision.macro  \
# VGG16          0.01             0.01      0.00          0.01             0.00
#
#        f1.macro
# VGG16      0.00

# %%
r = build_results_table(vgg16_coarse_test_res[0])
#r.to_csv('results.csv', index=True)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    print(r)
# Out:
#                       Atributo       Tipo  Frecuencia real  \
# 0                       a-line      Forma                0
# 1                     abstract      Forma              418
# 2             abstract chevron      Forma              767
# 3       abstract chevron print      Forma               16
# 4             abstract diamond      Forma                6
# 5              abstract floral      Forma                5
# 6        abstract floral print      Forma               53
# 7                 abstract geo      Forma               25
# 8           abstract geo print      Forma               31
# 9             abstract paisley      Forma               17
# 10            abstract pattern      Forma               14
# 11              abstract print      Forma               26
# 12            abstract printed      Forma              289
# 13             abstract stripe      Forma               23
# 14                        acid      Forma               14
# 15                   acid wash      Forma              276
# 16                   americana      Forma              214
# 17                     angeles      Forma               18
# 18                      animal      Forma               74
# 19                animal print      Forma              158
# 20                       ankle      Forma               93
# 21                    applique      Forma              164
# 22                arrow collar      Forma               28
# 23                         art      Forma               19
# 24                  asymmetric      Forma               70
# 25                asymmetrical      Forma              116
# 26            asymmetrical hem      Forma              152
# 27                    athletic      Forma               25
# 28                      audrey      Forma              122
# 29                        babe      Forma               29
# 30                    babydoll      Forma               40
# 31                    back bow      Forma              170
# 32                 back cutout      Forma                7
# 33                   back knit      Forma               13
# 34                   back lace      Forma               14
# 35                back striped      Forma               16
# 36                    backless      Forma                9
# 37                        baja      Forma              160
# 38                     bandage      Forma               21
# 39                     bandana      Forma              132
# 40               bandana print      Forma               84
# 41                      barbie      Forma               50
# 42                     baroque      Forma               37
# 43               baroque print      Forma              176
# 44                    baseball      Forma               85
# 45                       basic      Forma              262
# 46                    basquiat      Forma              218
# 47                     batwing      Forma               19
# 48                       beach      Forma              140
# 49                        bead      Forma              238
# 50                      beaded      Forma               37
# 51              beaded chiffon      Forma              379
# 52               beaded collar      Forma               20
# 53                beaded sheer      Forma               10
# 54                beaded shift      Forma                9
# 55                     beatles      Forma               12
# 56                         bed      Forma               29
# 57                   bejeweled      Forma               14
# 58                        bell      Forma               17
# 59                 bell-sleeve      Forma              124
# 60                       bella      Forma               14
# 61                      belted      Forma               51
# 62              belted chiffon      Forma              517
# 63               belted floral      Forma               15
# 64         belted floral print      Forma               16
# 65                 belted lace      Forma                8
# 66                 belted maxi      Forma               10
# 67                belted plaid      Forma               18
# 68                     bermuda      Forma               12
# 69                         bib      Forma               59
# 70                         big      Forma               34
# 71                        bike      Forma              186
# 72                       biker      Forma               21
# 73                        bird      Forma              102
# 74                  bird print      Forma               80
# 75                        blah      Forma               47
# 76                      bleach      Forma                9
# 77                    bleached      Forma               33
# 78              bleached denim      Forma               51
# 79                     blurred      Forma               16
# 80                   boat neck      Forma                8
# 81                     bodycon      Forma               60
# 82                bodycon midi      Forma              854
# 83                        boho      Forma               56
# 84                        bold      Forma              291
# 85                   botanical      Forma               75
# 86             botanical print      Forma               47
# 87                         bow      Forma               14
# 88                    bow-back      Forma              242
# 89                   bow-front      Forma                8
# 90                         box      Forma               13
# 91                   box pleat      Forma               84
# 92                 box-pleated      Forma               38
# 93                        boxy      Forma               10
# 94                   boxy crop      Forma              479
# 95                   boxy knit      Forma               33
# 96                   boxy lace      Forma                8
# 97                 boxy pocket      Forma                7
# 98                boxy striped      Forma               14
# 99                   boyfriend      Forma               17
# 100                    braided      Forma              278
# 101                     breton      Forma               59
# 102              breton stripe      Forma               19
# 103                    brocade      Forma                9
# 104                   brooklyn      Forma               51
# 105              brooklyn nets      Forma               93
# 106                brushstroke      Forma               53
# 107          brushstroke print      Forma               20
# 108                    burnout      Forma               14
# 109                    bustier      Forma              176
# 110                  butterfly      Forma               58
# 111            butterfly print      Forma               93
# 112                     button      Forma               42
# 113               button-front      Forma              725
# 114                   buttoned      Forma               40
# 115                      cable      Forma              101
# 116                 cable knit      Forma              234
# 117                 cable-knit      Forma              172
# 118                      caged      Forma               38
# 119                 california      Forma               53
# 120                     camera      Forma               85
# 121                       cami      Forma               12
# 122                  cami crop      Forma              546
# 123                  cami maxi      Forma                4
# 124                       camo      Forma               24
# 125                 camouflage      Forma              134
# 126                      candy      Forma               45
# 127                     canvas      Forma               52
# 128                 cap-sleeve      Forma               40
# 129                      capri      Forma               41
# 130                     cardio      Forma              232
# 131                      cargo      Forma                8
# 132                        cat      Forma              120
# 133                   chambray      Forma               88
# 134        chambray drawstring      Forma              304
# 135                    checked      Forma                6
# 136                  checkered      Forma               17
# 137                    cheetah      Forma               33
# 138                   chenille      Forma               22
# 139                    chevron      Forma               10
# 140              chevron print      Forma              196
# 141                       chic      Forma               48
# 142                    chiffon      Forma              259
# 143             chiffon floral      Forma             1596
# 144               chiffon lace      Forma               16
# 145            chiffon layered      Forma               13
# 146               chiffon maxi      Forma               10
# 147            chiffon paneled      Forma               83
# 148            chiffon pleated      Forma               11
# 149              chiffon shift      Forma               16
# 150              chiffon shirt      Forma               25
# 151           chiffon surplice      Forma               61
# 152            chiffon-paneled      Forma               22
# 153                      chino      Forma               22
# 154                     chunky      Forma              139
# 155                chunky knit      Forma              131
# 156                    cinched      Forma               62
# 157                     circle      Forma               13
# 158                     cities      Forma               52
# 159                       city      Forma               10
# 160                      civil      Forma              113
# 161                   clashist      Forma               22
# 162                    classic      Forma               10
# 163             classic cotton      Forma              995
# 164               classic crew      Forma               17
# 165          classic crew neck      Forma               11
# 166              classic denim      Forma               11
# 167                classic fit      Forma               39
# 168               classic knit      Forma               35
# 169             classic pocket      Forma               29
# 170             classic skinny      Forma                8
# 171            classic striped      Forma               17
# 172             classic v-neck      Forma               17
# 173              classic woven      Forma               22
# 174                      clean      Forma               29
# 175                 clean wash      Forma               58
# 176                      cloud      Forma               25
# 177                 cloud wash      Forma               45
# 178                      coast      Forma               29
# 179                     coated      Forma               37
# 180                     coffee  Estampado               20
# 181                     collar  Estampado               40
# 182                collar lace  Estampado              738
# 183                   collared  Estampado                6
# 184                 collarless  Estampado              101
# 185            collarless faux  Estampado              205
# 186                 colorblock  Estampado               15
# 187          colorblock pocket  Estampado              335
# 188               colorblocked  Estampado               14
# 189                      combo  Estampado              105
# 190                 combo maxi  Estampado              128
# 191                   contrast  Estampado                8
# 192              contrast trim  Estampado              284
# 193           contrast-trimmed  Estampado               47
# 194                convertible  Estampado                6
# 195                   corduroy  Estampado               25
# 196                     cotton  Estampado               27
# 197          cotton drawstring  Estampado              991
# 198                cotton knit  Estampado                8
# 199               cotton-blend  Estampado               15
# 200                   cover-up  Estampado               25
# 201                       cowl  Estampado               20
# 202                  cowl neck  Estampado              111
# 203                       cozy  Estampado               85
# 204                      crepe  Estampado               95
# 205                crepe shift  Estampado              498
# 206                crepe woven  Estampado               16
# 207                       crew  Estampado               33
# 208                  crew neck  Estampado              350
# 209                   crinkled  Estampado              234
# 210                 crisscross  Estampado               44
# 211            crisscross-back  Estampado               82
# 212                    crochet  Estampado               11
# 213               crochet crop  Estampado             1225
# 214        crochet embroidered  Estampado               15
# 215             crochet floral  Estampado               13
# 216             crochet fringe  Estampado               28
# 217               crochet knit  Estampado               15
# 218               crochet lace  Estampado               25
# 219               crochet maxi  Estampado              173
# 220               crochet mesh  Estampado               27
# 221            crochet overlay  Estampado               13
# 222            crochet-paneled  Estampado               11
# 223            crochet-trimmed  Estampado               56
# 224                  crocheted  Estampado               34
# 225             crocheted lace  Estampado              100
# 226                       crop  Estampado               14
# 227                    cropped  Estampado              902
# 228               cropped knit  Estampado              517
# 229                 cross-back  Estampado                7
# 230                  crossback  Estampado                7
# 231                     cuffed  Estampado               29
# 232               cuffed denim  Estampado              199
# 233              cuffed-sleeve  Estampado               41
# 234                     curved  Estampado               12
# 235                 curved hem  Estampado               70
# 236                        cut  Estampado               53
# 237                       cute  Estampado              546
# 238                     cutoff  Estampado              359
# 239                     cutout  Estampado               57
# 240                cutout lace  Estampado              470
# 241                cutout maxi  Estampado                5
# 242              cutout sheath  Estampado               17
# 243                cutout-back  Estampado                6
# 244                     dainty  Estampado               37
# 245                      daisy  Estampado               35
# 246                daisy print  Estampado              218
# 247                     damask  Estampado               78
# 248                     daring  Estampado               25
# 249                       dark  Estampado               20
# 250                    darling  Estampado              260
# 251                deep v-neck  Estampado               41
# 252                     deep-v  Estampado               56
# 253                    defyant  Estampado                1
# 254                      denim  Estampado               13
# 255           denim drawstring  Estampado             1817
# 256               denim pencil  Estampado                9
# 257                denim shift  Estampado               30
# 258                denim shirt  Estampado               10
# 259               denim skater  Estampado               49
# 260              denim utility  Estampado               19
# 261                     desert  Estampado               13
# 262                  destroyed  Estampado               13
# 263                      devil  Estampado              121
# 264                    diamond  Estampado                7
# 265              diamond print  Estampado              195
# 266                    dip-dye  Estampado               48
# 267                   dip-dyed  Estampado                9
# 268                 distressed  Estampado               10
# 269        distressed low-rise  Estampado              530
# 270        distressed mid-rise  Estampado                8
# 271          distressed skinny  Estampado                9
# 272                      ditsy  Estampado               29
# 273               ditsy floral  Estampado              122
# 274         ditsy floral print  Estampado               99
# 275                       doll  Estampado               44
# 276                     dolman  Estampado               55
# 277              dolman sleeve  Estampado              289
# 278              dolman-sleeve  Estampado               90
# 279                    dolphin  Estampado               18
# 280                dolphin hem  Estampado              108
# 281                     doodle  Estampado               25
# 282                        dot  Estampado                8
# 283                       dots  Estampado              535
# 284                     dotted  Estampado              135
# 285            double-breasted  Estampado               73
# 286                drape-front  Estampado               35
# 287                     draped  Estampado                7
# 288          draped open-front  Estampado              284
# 289               draped shawl  Estampado                6
# 290            draped surplice  Estampado                8
# 291                     drapey  Estampado                7
# 292                 drawstring  Estampado               71
# 293                      dream  Estampado              625
# 294               dreamcatcher  Estampado               57
# 295                    dreamer  Estampado                5
# 296                 drop waist  Estampado               12
# 297                drop-sleeve  Estampado               62
# 298                 drop-waist  Estampado               12
# 299                    dropped  Estampado               13
# 300                        dye  Estampado               36
# 301                   dynamite  Estampado              337
# 302                      eagle  Estampado               10
# 303                       edge  Estampado              105
# 304                     eiffel  Estampado               72
# 305                elasticized  Estampado               12
# 306                    elegant  Estampado               17
# 307                   elephant  Estampado              195
# 308             elephant print  Estampado               88
# 309                embellished  Estampado               42
# 310                embroidered  Estampado              224
# 311            embroidered fit  Estampado              985
# 312         embroidered floral  Estampado               10
# 313          embroidered gauze  Estampado               38
# 314  embroidered gauze peasant  Estampado               39
# 315           embroidered lace  Estampado                9
# 316           embroidered maxi  Estampado               73
# 317           embroidered mesh  Estampado                8
# 318        embroidered peasant  Estampado               40
# 319          embroidered shift  Estampado               45
# 320          embroidered woven  Estampado               17
# 321                 embroidery  Estampado               12
# 322                  enchanted  Estampado              263
# 323                   ethereal  Estampado               21
# 324                   everyday  Estampado               12
# 325                    eyelash  Estampado              128
# 326               eyelash knit  Estampado              141
# 327               eyelash lace  Estampado               10
# 328                     eyelet  Estampado              109
# 329                 eyelet fit  Estampado               99
# 330                      faded  Estampado               16
# 331                       fair  Estampado              140
# 332                  fair isle  Estampado               34
# 333                        fan  Estampado               25
# 334                      fancy  Estampado               19
# 335                       faux  Estampado               55
# 336                   faux fur     Tejido              981
# 337               faux leather     Tejido              211
# 338          faux leather mini     Tejido              578
# 339          faux leather moto     Tejido               13
# 340       faux leather paneled     Tejido               20
# 341        faux leather pencil     Tejido                4
# 342        faux leather skater     Tejido               14
# 343       faux leather varsity     Tejido               14
# 344       faux leather-paneled     Tejido                7
# 345       faux leather-trimmed     Tejido               11
# 346             faux shearling     Tejido                7
# 347                 faux suede     Tejido               30
# 348                  faux-wrap     Tejido               38
# 349                    feather     Tejido               10
# 350                    festive     Tejido               42
# 351                      field     Tejido               11
# 352                  fisherman     Tejido               17
# 353                        fit     Tejido               23
# 354                  fit flare     Tejido             1051
# 355                 fit skinny     Tejido               71
# 356                     fitted     Tejido                8
# 357              fitted v-neck     Tejido              178
# 358                      flare     Tejido               11
# 359                     flared     Tejido              664
# 360                       flat     Tejido               80
# 361                 flat front     Tejido              104
# 362                 flat-front     Tejido               70
# 363                   flawless     Tejido               22
# 364                     flirty     Tejido                9
# 365                     floral     Tejido               24
# 366             floral flutter     Tejido             3271
# 367                floral knit     Tejido               11
# 368                floral lace     Tejido               10
# 369           floral lace mini     Tejido              294
# 370         floral lace sheath     Tejido               10
# 371         floral lace skater     Tejido                8
# 372                floral maxi     Tejido               16
# 373                floral mesh     Tejido               58
# 374                floral midi     Tejido               17
# 375                floral mini     Tejido               10
# 376             floral paisley     Tejido                7
# 377             floral pattern     Tejido               15
# 378             floral peasant     Tejido               27
# 379             floral pleated     Tejido                5
# 380               floral print     Tejido                8
# 381        floral print skater     Tejido             1012
# 382     floral print strapless     Tejido               20
# 383      floral print surplice     Tejido                6
# 384               floral shift     Tejido               19
# 385              floral skater     Tejido               13
# 386            floral surplice     Tejido               45
# 387            floral textured     Tejido               17
# 388         floral-embroidered     Tejido                6
# 389                    flounce     Tejido               24
# 390               flounce maxi     Tejido               75
# 391                   flounced     Tejido                9
# 392                     flower     Tejido               43
# 393                      flowy     Tejido              210
# 394                      floyd     Tejido               96
# 395                     fluted     Tejido               13
# 396                    flutter     Tejido               25
# 397             flutter sleeve     Tejido              102
# 398             flutter-sleeve     Tejido               75
# 399                       foil     Tejido               20
# 400                  fold-over     Tejido               23
# 401                   foldover     Tejido               28
# 402                       folk     Tejido               31
# 403                 folk print     Tejido               26
# 404                    foulard     Tejido                9
# 405                        fox     Tejido                9
# 406                     france     Tejido               61
# 407                     frayed     Tejido               19
# 408                free spirit     Tejido               71
# 409                     french     Tejido               33
# 410               french terry     Tejido              299
# 411                      fresh     Tejido              178
# 412                      frida     Tejido               59
# 413                     fringe     Tejido               13
# 414                    fringed     Tejido              321
# 415                        fur     Tejido              109
# 416                      fuzzy     Tejido              272
# 417                 fuzzy knit     Tejido              103
# 418                     galaxy     Tejido               25
# 419                     garden     Tejido               50
# 420               garden party     Tejido               53
# 421         gathered waistline     Tejido               17
# 422                     gaucho     Tejido               36
# 423                      gauze     Tejido                3
# 424                 gauze maxi     Tejido              173
# 425              gauze peasant     Tejido               19
# 426                      gauzy     Tejido               10
# 427                        gem     Tejido               19
# 428                    genuine     Tejido                8
# 429                        geo     Tejido               19
# 430                geo pattern     Tejido              291
# 431                  geo print     Tejido               14
# 432                 geo stripe     Tejido              113
# 433                  georgette     Tejido               18
# 434                    gingham     Tejido               56
# 435                    giraffe     Tejido               45
# 436              giraffe print     Tejido               22
# 437                       girl     Tejido               14
# 438                      girls     Tejido              266
# 439                      glass     Tejido              329
# 440                    glitter     Tejido               11
# 441                    graphic     Tejido               37
# 442             graphic muscle     Tejido              955
# 443          graphic racerback     Tejido               46
# 444                       grid     Tejido                7
# 445                 grid print     Tejido               45
# 446                     grunge     Tejido               23
# 447                       guns     Tejido               91
# 448                      halen     Tejido               30
# 449                      harem     Tejido                6
# 450                      heart     Tejido               81
# 451                heart print     Tejido              179
# 452                       heat     Tejido               39
# 453                  heathered     Tejido               53
# 454             heathered knit     Tejido              324
# 455           heathered stripe     Tejido               22
# 456           heathered v-neck     Tejido                7
# 457                        hem     Tejido                7
# 458                    hepburn     Tejido              509
# 459                     heroes     Tejido               20
# 460                herringbone     Tejido                9
# 461                   high-low     Tejido               23
# 462                  high-neck     Tejido               65
# 463                  high-rise     Tejido               21
# 464           high-rise skinny     Tejido               37
# 465                  high-slit     Tejido                7
# 466             high-slit maxi     Tejido               47
# 467                 high-waist     Tejido                5
# 468               high-waisted     Tejido               46
# 469                       hood     Tejido              118
# 470                     hooded     Tejido               64
# 471                hooded maxi     Tejido              538
# 472             hooded utility     Tejido               17
# 473                houndstooth     Tejido               19
# 474                       ikat     Tejido               57
# 475                 ikat print     Tejido               96
# 476                   illusion     Tejido               50
# 477          illusion neckline     Tejido               86
# 478                      inset     Tejido                5
# 479                   internet     Tejido               52
# 480                     island     Tejido               11
# 481                       isle     Tejido              140
# 482                   jacquard     Tejido               25
# 483                       joie     Tejido              118
# 484                      kahlo     Tejido               71
# 485               kaleidoscope     Tejido               11
# 486         kaleidoscope print     Tejido               50
# 487                   kangaroo     Tejido               27
# 488            kangaroo pocket     Tejido               36
# 489                    keyhole     Tejido                6
# 490                        kid     Tejido              100
# 491                     killin     Tejido               14
# 492                       kiss     Tejido                5
# 493                      kitty     Tejido               29
# 494                knee-length     Tejido               17
# 495                       knit     Tejido               19
# 496                  knit lace     Tejido             2566
# 497              knit longline     Tejido               11
# 498                  knit maxi     Tejido               15
# 499                  knit mini     Tejido               37
# 500                  knit open     Tejido               19
# 501                knit pencil     Tejido               33
# 502                knit pocket     Tejido               38
# 503                knit raglan     Tejido               12
# 504                 knit shawl     Tejido               13
# 505                knit skater     Tejido               14
# 506                knit stripe     Tejido               42
# 507               knit striped     Tejido                8
# 508               knit trapeze     Tejido               21
# 509                knit v-neck     Tejido               13
# 510                    knotted     Tejido               19
# 511                       kurt     Tejido               48
# 512                         la     Tejido               14
# 513                       lace     Tejido              208
# 514               lace layered     Tejido             2836
# 515                  lace maxi     Tejido                9
# 516                  lace mesh     Tejido               54
# 517                  lace midi     Tejido               20
# 518                  lace mini     Tejido                9
# 519               lace overlay     Tejido               33
# 520                 lace panel     Tejido               61
# 521               lace paneled     Tejido               80
# 522                lace pencil     Tejido               52
# 523                lace peplum     Tejido               30
# 524               lace pleated     Tejido               16
# 525                 lace print     Tejido                9
# 526                lace sheath     Tejido               30
# 527                 lace sheer     Tejido               52
# 528                 lace shift     Tejido                8
# 529                lace skater     Tejido               51
# 530                lace sleeve     Tejido               35
# 531                  lace trim     Tejido               15
# 532               lace-paneled     Tejido              187
# 533                  lace-trim     Tejido               99
# 534               lace-trimmed     Tejido               28
# 535                    lace-up     Tejido               42
# 536                       lacy     Tejido               36
# 537                ladder-back     Tejido               23
# 538                       lady     Tejido                6
# 539                     lakers     Tejido              162
# 540                      lapel     Tejido               24
# 541                      laser     Tejido               61
# 542                    lattice     Tejido               29
# 543                    layered     Tejido               26
# 544                       leaf     Tejido              256
# 545                 leaf print     Tejido               94
# 546                    leather     Tejido               56
# 547               leather mini     Tejido             1019
# 548               leather moto     Tejido               18
# 549            leather paneled     Tejido               32
# 550             leather pencil     Tejido                6
# 551             leather peplum     Tejido               19
# 552            leather quilted     Tejido                8
# 553             leather skater     Tejido                7
# 554            leather trimmed     Estilo               18
# 555            leather varsity     Estilo                5
# 556            leather-paneled     Estilo                8
# 557            leather-trimmed     Estilo               11
# 558                      leave     Estilo               11
# 559                        led     Estilo               17
# 560                    leopard     Estilo               10
# 561              leopard print     Estilo              263
# 562                       life     Estilo              157
# 563                      light     Estilo              189
# 564                  lightning     Estilo              345
# 565                      linen     Estilo                7
# 566                linen-blend     Estilo              418
# 567                       logo     Estilo               56
# 568                long sleeve     Estilo              128
# 569                long-sleeve     Estilo              847
# 570               long-sleeved     Estilo              115
# 571                   longline     Estilo               34
# 572             longline shirt     Estilo              467
# 573                       loop     Estilo               13
# 574                      loose     Estilo               18
# 575                 loose-knit     Estilo              392
# 576                     lounge     Estilo               11
# 577                       love     Estilo               52
# 578                      lover     Estilo              839
# 579                   low-rise     Estilo               19
# 580            low-rise skinny     Estilo               37
# 581                      loyal     Estilo               14
# 582                       luxe     Estilo                5
# 583                     m-slit     Estilo               44
# 584                m-slit maxi     Estilo               10
# 585                    mandala     Estilo                5
# 586              mandala print     Estilo               40
# 587                   mandarin     Estilo               21
# 588                        map     Estilo               63
# 589                     marble     Estilo               23
# 590               marble print     Estilo               33
# 591                    marilyn     Estilo               18
# 592             marilyn monroe     Estilo               46
# 593                     marled     Estilo               34
# 594              marled stripe     Estilo              360
# 595                    matelot     Estilo                8
# 596                       maxi     Estilo               16
# 597                  medallion     Estilo             2194
# 598            medallion print     Estilo               60
# 599                     medium     Estilo               31
# 600                       meow     Estilo              188
# 601                       mesh     Estilo                8
# 602               mesh overlay     Estilo              705
# 603                 mesh panel     Estilo               13
# 604               mesh paneled     Estilo               63
# 605             mesh racerback     Estilo               37
# 606               mesh-paneled     Estilo               14
# 607               mesh-trimmed     Estilo               39
# 608                   metallic     Estilo                6
# 609                      miami     Estilo              286
# 610                     mickey     Estilo               68
# 611               mickey mouse     Estilo               38
# 612                   mid rise     Estilo               25
# 613            mid rise skinny     Estilo               48
# 614                   mid-rise     Estilo               15
# 615            mid-rise skinny     Estilo               55
# 616                       midi     Estilo               16
# 617                       mina     Estilo              613
# 618                    mineral     Estilo               12
# 619               mineral wash     Estilo              143
# 620                       mini     Estilo              125
# 621                     minnie     Estilo              835
# 622               minnie mouse     Estilo               17
# 623                   mirrored     Estilo                8
# 624                      mixed     Estilo                5
# 625                mixed print     Estilo              164
# 626               mixed stripe     Estilo               31
# 627                        mob     Estilo               19
# 628                       mock     Estilo               18
# 629                  mock neck     Estilo               79
# 630                  mock-neck     Estilo               61
# 631                        mod     Estilo                8
# 632                  modernist     Estilo               60
# 633                     monroe     Estilo                6
# 634                       moon     Estilo               37
# 635                    morning     Estilo               44
# 636                     mosaic     Estilo               15
# 637               mosaic print     Estilo               32
# 638                       moto     Estilo               15
# 639               multi-stripe     Estilo              200
# 640                     muscle     Estilo                9
# 641                       muse     Estilo              754
# 642                   nautical     Estilo               18
# 643            nautical stripe     Estilo               50
# 644           nautical striped     Estilo               14
# 645                neck ribbed     Estilo                9
# 646                neck skater     Estilo               13
# 647               neck striped     Estilo               10
# 648                   neckline     Estilo                9
# 649                       neon     Estilo              181
# 650                   neoprene     Estilo              145
# 651                       nets     Estilo               26
# 652                     netted     Estilo               54
# 653                   new york     Estilo               15
# 654                      night     Estilo              252
# 655             notched collar     Estilo               72
# 656                  notorious     Estilo               11
# 657                         ny     Estilo               10
# 658                        nyc     Estilo               44
# 659                      nylon     Estilo               68
# 660           off-the-shoulder     Estilo               44
# 661                        oil     Estilo               26
# 662                      ombre     Estilo               11
# 663                 one-button     Estilo              102
# 664               one-shoulder     Estilo               15
# 665                  open-back     Estilo               11
# 666                 open-front     Estilo               26
# 667                  open-knit     Estilo              135
# 668              open-shoulder     Estilo              112
# 669                    organza     Estilo               10
# 670                    origami     Estilo              101
# 671                     ornate     Estilo               16
# 672             ornate paisley     Estilo               67
# 673               ornate print     Estilo                4
# 674                    overlay     Estilo               18
# 675             overlay sheath     Estilo              139
# 676                  oversized     Estilo                8
# 677                     oxford     Estilo              282
# 678                      paint     Estilo               42
# 679             paint splatter     Estilo               53
# 680                    painted     Estilo               16
# 681                    paisley     Estilo               37
# 682              paisley print     Estilo              480
# 683                       palm     Estilo              198
# 684                 palm print     Estilo              122
# 685               palm springs     Estilo               34
# 686                  palm tree     Estilo                8
# 687                        pan     Estilo               51
# 688                      panel     Estilo               69
# 689                    paneled     Estilo              320
# 690                   paradise     Estilo              229
# 691                      paris     Estilo               19
# 692                      party     Estilo              135
# 693                    patched     Estilo              395
# 694                  patchwork     Estilo               12
# 695                    pattern     Estilo              100
# 696                  patterned     Estilo              468
# 697                    peasant     Estilo              102
# 698                     pencil     Estilo              295
# 699                     peplum     Estilo              488
# 700                 perforated     Estilo              235
# 701                performance     Estilo               45
# 702                       pima     Estilo              142
# 703                        pin     Estilo               21
# 704                  pineapple     Estilo               62
# 705                       pink     Estilo               25
# 706                  pinstripe     Estilo              924
# 707                 pinstriped     Estilo               36
# 708                    pintuck     Estilo               15
# 709            pintuck pleated     Estilo              117
# 710                  pintucked     Estilo                5
# 711                      pizza     Estilo               55
# 712                         pj     Estilo               28
# 713                      plaid     Estilo               54
# 714                plaid shirt     Estilo              514
# 715                     please     Estilo               60
# 716                      pleat     Estilo               12
# 717                    pleated     Estilo              146
# 718             pleated skater     Estilo              947
# 719              pleated woven     Estilo               14
# 720                     pocket     Estilo               19
# 721                  pointelle     Estilo              702
# 722                  polka dot     Estilo               40
# 723                       polo     Estilo              511
# 724                    pom-pom     Estilo              146
# 725                      ponte     Estilo               31
# 726                    popcorn     Estilo               84
# 727                    popover     Estilo               18
# 728                       posh     Estilo               63
# 729                      power     Estilo               22
# 730                      print     Estilo               24
# 731            print racerback     Estilo             5178
# 732                print satin     Estilo               13
# 733                print scuba     Estilo                8
# 734                print shift     Estilo               21
# 735                print shirt     Estilo               61
# 736               print skater     Estilo              117
# 737                print smock     Estilo               67
# 738              print smocked     Estilo                6
# 739            print strapless     Estilo                9
# 740              print strappy     Estilo               32
# 741             print surplice     Estilo               18
# 742                print tulip     Estilo               39
# 743               print v-neck     Estilo                7
# 744                print woven     Estilo               17
# 745                    printed     Estilo               40
# 746                     puffer     Estilo              873
# 747                   pullover     Estilo               65
# 748                       purl     Estilo              294
# 749                    quilted     Estilo               14
# 750                     quirky     Estilo              243
# 751                  racerback     Estilo               11
# 752                        rad     Estilo              421
# 753                       raga     Estilo               13
# 754                     raglan     Estilo               25
# 755              raglan sleeve     Estilo              280
# 756                    rainbow     Estilo               33
# 757                        raw     Estilo               88
# 758                    raw-cut     Estilo               69
# 759                      rebel     Estilo               16
# 760                        red     Estilo               16
# 761                    refined     Estilo              969
# 762                     regime     Estilo               15
# 763                    relaxed     Estilo               14
# 764                      retro     Estilo               97
# 765                    reverse     Estilo              250
# 766                 reversible     Estilo               35
# 767                 rhinestone     Estilo               25
# 768                        rib     Estilo               67
# 769                   rib-knit     Estilo              115
# 770                     ribbed     Estilo                9
# 771              ribbed stripe     Estilo              415
# 772                ribbed-knit     Estilo                4
# ...
# 754                    209    0    209    0.00       0.00 0.00
# 755                      0    0      0    0.00       0.00 0.00
# 756                      0    0      0    0.00       0.00 0.00
# 757                      0    0      0    0.00       0.00 0.00
# 758                      0    0      0    0.00       0.00 0.00
# 759                      0    0      0    0.00       0.00 0.00
# 760                    357    0    357    0.00       0.00 0.00
# 761                      0    0      0    0.00       0.00 0.00
# 762                      0    0      0    0.00       0.00 0.00
# 763                      0    0      0    0.00       0.00 0.00
# 764                      0    0      0    0.00       0.00 0.00
# 765                      0    0      0    0.00       0.00 0.00
# 766                      0    0      0    0.00       0.00 0.00
# 767                      0    0      0    0.00       0.00 0.00
# 768                      0    0      0    0.00       0.00 0.00
# 769                      0    0      0    0.00       0.00 0.00
# 770                     62    0     62    0.00       0.00 0.00
# 771                      0    0      0    0.00       0.00 0.00
# 772                      0    0      0    0.00       0.00 0.00
# 773                      0    0      0    0.00       0.00 0.00
# 774                    116    0    116    0.00       0.00 0.00
# 775                    168    8    160    0.04       0.05 0.00
# 776                      0    0      0    0.00       0.00 0.00
# 777                      0    0      0    0.00       0.00 0.00
# 778                      0    0      0    0.00       0.00 0.00
# 779                      0    0      0    0.00       0.00 0.00
# 780                      0    0      0    0.00       0.00 0.00
# 781                    569    1    568    0.14       0.00 0.00
# 782                      0    0      0    0.00       0.00 0.00
# 783                      0    0      0    0.00       0.00 0.00
# 784                      0    0      0    0.00       0.00 0.00
# 785                      0    0      0    0.00       0.00 0.00
# 786                      0    0      0    0.00       0.00 0.00
# 787                      0    0      0    0.00       0.00 0.00
# 788                      0    0      0    0.00       0.00 0.00
# 789                      0    0      0    0.00       0.00 0.00
# 790                      0    0      0    0.00       0.00 0.00
# 791                      0    0      0    0.00       0.00 0.00
# 792                      0    0      0    0.00       0.00 0.00
# 793                      4    0      4    0.00       0.00 0.00
# 794                      0    0      0    0.00       0.00 0.00
# 795                      0    0      0    0.00       0.00 0.00
# 796                      0    0      0    0.00       0.00 0.00
# 797                      0    0      0    0.00       0.00 0.00
# 798                      0    0      0    0.00       0.00 0.00
# 799                      0    0      0    0.00       0.00 0.00
# 800                     48    0     48    0.00       0.00 0.00
# 801                      0    0      0    0.00       0.00 0.00
# 802                      0    0      0    0.00       0.00 0.00
# 803                      0    0      0    0.00       0.00 0.00
# 804                      0    0      0    0.00       0.00 0.00
# 805                      0    0      0    0.00       0.00 0.00
# 806                     42    0     42    0.00       0.00 0.00
# 807                      0    0      0    0.00       0.00 0.00
# 808                      0    0      0    0.00       0.00 0.00
# 809                      0    0      0    0.00       0.00 0.00
# 810                      0    0      0    0.00       0.00 0.00
# 811                      0    0      0    0.00       0.00 0.00
# 812                      0    0      0    0.00       0.00 0.00
# 813                      0    0      0    0.00       0.00 0.00
# 814                      0    0      0    0.00       0.00 0.00
# 815                     20    0     20    0.00       0.00 0.00
# 816                      0    0      0    0.00       0.00 0.00
# 817                   1098    0   1098    0.00       0.00 0.00
# 818                     12    0     12    0.00       0.00 0.00
# 819                      0    0      0    0.00       0.00 0.00
# 820                   1520    0   1520    0.00       0.00 0.00
# 821                      0    0      0    0.00       0.00 0.00
# 822                  14915   11  14904    0.16       0.00 0.00
# 823                      0    0      0    0.00       0.00 0.00
# 824                      0    0      0    0.00       0.00 0.00
# 825                      0    0      0    0.00       0.00 0.00
# 826                      0    0      0    0.00       0.00 0.00
# 827                      0    0      0    0.00       0.00 0.00
# 828                      0    0      0    0.00       0.00 0.00
# 829                      0    0      0    0.00       0.00 0.00
# 830                   3630    0   3630    0.00       0.00 0.00
# 831                   2873    7   2866    0.01       0.00 0.00
# 832                      0    0      0    0.00       0.00 0.00
# 833                      0    0      0    0.00       0.00 0.00
# 834                      0    0      0    0.00       0.00 0.00
# 835                      0    0      0    0.00       0.00 0.00
# 836                  19367   27  19340    0.44       0.00 0.00
# 837                   3769   95   3674    0.04       0.03 0.00
# 838                      0    0      0    0.00       0.00 0.00
# 839                    829    0    829    0.00       0.00 0.00
# 840                      0    0      0    0.00       0.00 0.00
# 841                    307    1    306    0.01       0.00 0.00
# 842                      0    0      0    0.00       0.00 0.00
# 843                     19    0     19    0.00       0.00 0.00
# 844                      0    0      0    0.00       0.00 0.00
# 845                      0    0      0    0.00       0.00 0.00
# 846                      0    0      0    0.00       0.00 0.00
# 847                      0    0      0    0.00       0.00 0.00
# 848                      0    0      0    0.00       0.00 0.00
# 849                      0    0      0    0.00       0.00 0.00
# 850                      0    0      0    0.00       0.00 0.00
# 851                      0    0      0    0.00       0.00 0.00
# 852                      0    0      0    0.00       0.00 0.00
# 853                      0    0      0    0.00       0.00 0.00
# 854                      0    0      0    0.00       0.00 0.00
# 855                      0    0      0    0.00       0.00 0.00
# 856                      0    0      0    0.00       0.00 0.00
# 857                      0    0      0    0.00       0.00 0.00
# 858                      0    0      0    0.00       0.00 0.00
# 859                      0    0      0    0.00       0.00 0.00
# 860                      0    0      0    0.00       0.00 0.00
# 861                      0    0      0    0.00       0.00 0.00
# 862                      0    0      0    0.00       0.00 0.00
# 863                      0    0      0    0.00       0.00 0.00
# 864                      0    0      0    0.00       0.00 0.00
# 865                      0    0      0    0.00       0.00 0.00
# 866                      0    0      0    0.00       0.00 0.00
# 867                      0    0      0    0.00       0.00 0.00
# 868                      0    0      0    0.00       0.00 0.00
# 869                      0    0      0    0.00       0.00 0.00
# 870                      0    0      0    0.00       0.00 0.00
# 871                      0    0      0    0.00       0.00 0.00
# 872                      0    0      0    0.00       0.00 0.00
# 873                      0    0      0    0.00       0.00 0.00
# 874                      0    0      0    0.00       0.00 0.00
# 875                      0    0      0    0.00       0.00 0.00
# 876                      0    0      0    0.00       0.00 0.00
# 877                      0    0      0    0.00       0.00 0.00
# 878                   1685   25   1660    0.15       0.01 0.00
# 879                      0    0      0    0.00       0.00 0.00
# 880                      0    0      0    0.00       0.00 0.00
# 881                    204    2    202    0.01       0.01 0.00
# 882                      0    0      0    0.00       0.00 0.00
# 883                   3494    3   3491    0.12       0.00 0.00
# 884                   4586  730   3856    0.64       0.16 0.20
# 885                      0    0      0    0.00       0.00 0.00
# 886                      0    0      0    0.00       0.00 0.00
# 887                    624    1    623    0.04       0.00 0.00
# 888                      0    0      0    0.00       0.00 0.00
# 889                      0    0      0    0.00       0.00 0.00
# 890                      0    0      0    0.00       0.00 0.00
# 891                      0    0      0    0.00       0.00 0.00
# 892                    763    2    761    0.02       0.00 0.00
# 893                      0    0      0    0.00       0.00 0.00
# 894                      0    0      0    0.00       0.00 0.00
# 895                      0    0      0    0.00       0.00 0.00
# 896                      0    0      0    0.00       0.00 0.00
# 897                      0    0      0    0.00       0.00 0.00
# 898                      0    0      0    0.00       0.00 0.00
# 899                      0    0      0    0.00       0.00 0.00
# 900                    134    1    133    0.00       0.01 0.00
# 901                     32    0     32    0.00       0.00 0.00
# 902                      0    0      0    0.00       0.00 0.00
# 903                      0    0      0    0.00       0.00 0.00
# 904                      0    0      0    0.00       0.00 0.00
# 905                      0    0      0    0.00       0.00 0.00
# 906                      0    0      0    0.00       0.00 0.00
# 907                    230    0    230    0.00       0.00 0.00
# 908                      0    0      0    0.00       0.00 0.00
# 909                      0    0      0    0.00       0.00 0.00
# 910                      0    0      0    0.00       0.00 0.00
# 911                      0    0      0    0.00       0.00 0.00
# 912                      0    0      0    0.00       0.00 0.00
# 913                     85    0     85    0.00       0.00 0.00
# 914                      0    0      0    0.00       0.00 0.00
# 915                      0    0      0    0.00       0.00 0.00
# 916                      0    0      0    0.00       0.00 0.00
# 917                      0    0      0    0.00       0.00 0.00
# 918                      0    0      0    0.00       0.00 0.00
# 919                      0    0      0    0.00       0.00 0.00
# 920                      0    0      0    0.00       0.00 0.00
# 921                      0    0      0    0.00       0.00 0.00
# 922                      0    0      0    0.00       0.00 0.00
# 923                      0    0      0    0.00       0.00 0.00
# 924                      0    0      0    0.00       0.00 0.00
# 925                      0    0      0    0.00       0.00 0.00
# 926                      0    0      0    0.00       0.00 0.00
# 927                      0    0      0    0.00       0.00 0.00
# 928                      0    0      0    0.00       0.00 0.00
# 929                      0    0      0    0.00       0.00 0.00
# 930                      0    0      0    0.00       0.00 0.00
# 931                     43    0     43    0.00       0.00 0.00
# 932                      0    0      0    0.00       0.00 0.00
# 933                   2552    3   2549    0.07       0.00 0.00
# 934                      0    0      0    0.00       0.00 0.00
# 935                     18    0     18    0.00       0.00 0.00
# 936                      0    0      0    0.00       0.00 0.00
# 937                    152    0    152    0.00       0.00 0.00
# 938                      0    0      0    0.00       0.00 0.00
# 939                      0    0      0    0.00       0.00 0.00
# 940                      0    0      0    0.00       0.00 0.00
# 941                      0    0      0    0.00       0.00 0.00
# 942                      0    0      0    0.00       0.00 0.00
# 943                     31    0     31    0.00       0.00 0.00
# 944                      0    0      0    0.00       0.00 0.00
# 945                      0    0      0    0.00       0.00 0.00
# 946                      0    0      0    0.00       0.00 0.00
# 947                      0    0      0    0.00       0.00 0.00
# 948                      0    0      0    0.00       0.00 0.00
# 949                      0    0      0    0.00       0.00 0.00
# 950                      0    0      0    0.00       0.00 0.00
# 951                      1    0      1    0.00       0.00 0.00
# 952                      0    0      0    0.00       0.00 0.00
# 953                      0    0      0    0.00       0.00 0.00
# 954                      0    0      0    0.00       0.00 0.00
# 955                      0    0      0    0.00       0.00 0.00
# 956                   2082    1   2081    0.11       0.00 0.00
# 957                      0    0      0    0.00       0.00 0.00
# 958                      1    0      1    0.00       0.00 0.00
# 959                      0    0      0    0.00       0.00 0.00
# 960                      0    0      0    0.00       0.00 0.00
# 961                      0    0      0    0.00       0.00 0.00
# 962                      0    0      0    0.00       0.00 0.00
# 963                      0    0      0    0.00       0.00 0.00
# 964                      0    0      0    0.00       0.00 0.00
# 965                      0    0      0    0.00       0.00 0.00
# 966                      0    0      0    0.00       0.00 0.00
# 967                      0    0      0    0.00       0.00 0.00
# 968                      0    0      0    0.00       0.00 0.00
# 969                   2635    0   2635    0.00       0.00 0.00
# 970                      0    0      0    0.00       0.00 0.00
# 971                      0    0      0    0.00       0.00 0.00
# 972                      0    0      0    0.00       0.00 0.00
# 973                      0    0      0    0.00       0.00 0.00
# 974                      0    0      0    0.00       0.00 0.00
# 975                      0    0      0    0.00       0.00 0.00
# 976                      0    0      0    0.00       0.00 0.00
# 977                      0    0      0    0.00       0.00 0.00
# 978                      0    0      0    0.00       0.00 0.00
# 979                      0    0      0    0.00       0.00 0.00
# 980                      0    0      0    0.00       0.00 0.00
# 981                      0    0      0    0.00       0.00 0.00
# 982                    226    0    226    0.00       0.00 0.00
# 983                    165    3    162    0.02       0.02 0.00
# 984                      0    0      0    0.00       0.00 0.00
# 985                      0    0      0    0.00       0.00 0.00
# 986                    784    0    784    0.00       0.00 0.00
# 987                      0    0      0    0.00       0.00 0.00
# 988                    325    1    324    0.01       0.00 0.00
# 989                      0    0      0    0.00       0.00 0.00
# 990                      0    0      0    0.00       0.00 0.00
# 991                      0    0      0    0.00       0.00 0.00
# 992                      0    0      0    0.00       0.00 0.00
# 993                    413    0    413    0.00       0.00 0.00
# 994                      0    0      0    0.00       0.00 0.00
# 995                      0    0      0    0.00       0.00 0.00
# 996                      0    0      0    0.00       0.00 0.00
# 997                      0    0      0    0.00       0.00 0.00
# 998                      0    0      0    0.00       0.00 0.00
# 999                      0    0      0    0.00       0.00 0.00

# %% [markdown]
# El valor de *top-5 recall* es 0.01, muy inferior al 0.54 que obtiene *FashionNet*, el modelo proporcionado junto con el dataset de *DeepFashion*.

# %% [markdown]
# ## 2.1 Modelos alternativos

# %% [markdown]
# Dado el pobre rendimiento obtenido con el clasificador anterior se probará varias alternativas para probar si con una simple red neuronal convolucional es posible obtener un rendimiento superior. Definimos el código necesario para estas versiones alternativas.

# %% [markdown]
# ### 2.1.1 Alternativa A: Entrenamiento a partir de Imagenet

# %% [markdown]
# Se va a entrenar el mismo modelo que el descrito en el apartado anterior, partiendo de los pesos entrenados a partir de ImageNet y no sobre el modelo entrenado con la versión reducida del conjunto de datos. Con esto se pretende descartar que el problema del bajo rendimiento sea el *transfer learning* entre la versión reducida y la versión completa.

# %%
# Alternativa A. Mismos parámetros que el modelo original, entrenado directamente a partir 
# de Imagenet y no a partir de la versión reducida del conjunto de datos. 
def build_VGG16a():
    base_model = VGG16(
        include_top=False,
        weights="imagenet",
        input_shape=(224,224,3),
        pooling='max',
        #classes=1000
        )
    freeze_all_layers(base_model)
    
    x = base_model.output
    x = Dense(496, activation="relu")(x)
    x = Dense(NUM_CLASSES, activation='sigmoid')(x)
    model = Model(inputs=base_model.input, outputs=x)
    
    return model


# %cache coarse_vgg162_a = train('VGG16a',model_id='coarse3', freeze_layers_ratio=0.80)
# %cache coarse_vgg162_a_test_res = evaluate('VGG16a', model_id = 'coarse3')
build_result_df([(coarse_vgg162_a_test_res[1], 'VGG16 alt. A')], k=5)
# Out:
# Loading cached value for variable 'coarse_vgg162_a'. Time since caching: 5 days, 15:12:07.485051
# Loading cached value for variable 'coarse_vgg162_a_test_res'. Time since caching: 5 days, 3:28:53.756745
#               recall.micro  precision.micro  f1.micro  recall.macro  \
# VGG16 alt. A          0.01             0.01      0.00          0.01
#
#               precision.macro  f1.macro
# VGG16 alt. A             0.00      0.00

# %% [markdown]
# El resultado obtenido es el mismo que en el apartado anterior.

# %% [markdown]
# ### 2.1.2 Alternativa B: Entrenamiento a partir de Imagenet aumentando el tamaño de las capas finales

# %% [markdown]
# Partiendo de los pesos de Imagenet, se emplea la misma arquitectura que en los modelos anteriores multiplicando x10 el número de neuronas en la penúltima capa densa. De esta forma se consigue que la última parte de la red tenga forma de embudo.

# %%
# Alternativa B. Mismos parámetros que el modelo original, entrenado directamente a partir 
# de Imagenet y no a partir de la versión reducida del conjunto de datos y aumentando el tamaño de la penúltima capa densa. 
def build_VGG16b():
    base_model = VGG16(
        include_top=False,
        weights="imagenet",
        input_shape=(224,224,3),
        pooling='max',
        #classes=1000
        )
    freeze_all_layers(base_model)
    
    x = base_model.output
    x = Dense(4096, activation="relu")(x)
    x = Dense(NUM_CLASSES, activation='sigmoid')(x)
    model = Model(inputs=base_model.input, outputs=x)
    
    return model


# %cache coarse_vgg162_b = train('VGG16b',model_id='coarse4', freeze_layers_ratio=0.80)
# %cache coarse_vgg162_b_test_res = evaluate('VGG16b', model_id = 'coarse4')
build_result_df([(coarse_vgg162_b_test_res[1], 'VGG16 alt. B')], k=5)
# Out:
# Loading cached value for variable 'coarse_vgg162_b'. Time since caching: 5 days, 4:05:29.797986
# Loading cached value for variable 'coarse_vgg162_b_test_res'. Time since caching: 5 days, 3:20:32.579847
#               recall.micro  precision.micro  f1.micro  recall.macro  \
# VGG16 alt. B          0.01             0.01      0.00          0.01
#
#               precision.macro  f1.macro
# VGG16 alt. B             0.00      0.00

# %% [markdown]
# ### 2.1.3 Alternativa C: Reducir el número de capas congeladas durante el entrenamiento

# %% [markdown]
# Partiendo del modelo entrenado con la versión reducida del conjunto de datos, se disminuye de 80% a 60% el porcentaje de capas congeladas durante la segunda fase de entrenamiento. Con esto se pretende comprobar si el problema del bajo rendimiento es que existe una gran diferencia entre los pesos entrenados a partir de Imagenet y el conjunto de datos actual en estas capas de la red.

# %%
# %cache coarse_vgg162_60 = train('VGG16',model_id='coarse2', freeze_layers_ratio=0.60)
# %cache coarse_vgg162_60_test_res = evaluate('VGG16', model_id = 'coarse2')
build_result_df([(coarse_vgg162_60_test_res[1], 'VGG16 alt. C')], k=5)
# Out:
# Loading cached value for variable 'coarse_vgg162_60'. Time since caching: 8 days, 12:37:20.797001
# Loading cached value for variable 'coarse_vgg162_60_test_res'. Time since caching: 5 days, 3:37:16.322829
#               recall.micro  precision.micro  f1.micro  recall.macro  \
# VGG16 alt. C          0.00             0.00      0.00          0.01
#
#               precision.macro  f1.macro
# VGG16 alt. C             0.00      0.00

# %% [markdown]
# ### 2.1.4 Alternativa D: Oversampling y undersampling.

# %% [markdown]
# Finalmente, se realiza la misma modificación de la partición de entrenamiento con la que mejores resultados se ha obtenido con la versión reducida del conjunto de datos. Recodemos que esta modificación consistía en reemplazar el 30% de las observaciones de la partición de entrenamiento con atributos mayoritarios por observaciones asociadas a atributos minoritarios. El código y la descripción este método están detallados en el *notebook* de [análisis](http://localhost:8888/notebooks/TFM%20akepa/attribute-detection-in-fashon-images/src/DeepFashion_VersionCompleta_Analisis.ipynb#Opci%C3%B3n-2:-Oversampling-y-undersampling-por-etiqueta)

# %%
# Sobreescribimos la función definida anteriormente para emplear el fichero modificado de datos
def build_iterator_dataframe(partition, attr_type=None):
    if partition == 'train':
        partition_attribute_filepath = ANNO_COARSE_PATH + "/oversampled.txt"
    else:
        partition_attribute_filepath = ANNO_COARSE_PATH + "/" + partition + "_attr.txt"
    names = []
    names.append('filename')
    names.extend(attributes)
    data = pd.read_csv(partition_attribute_filepath, sep = ' ', names = names, index_col=False)
    
    # Filtrado por tipo de atributo. Empleado para los clasificadores separados por tipo de atributo. 
    if attr_type is not None:
        columns = attr_type_to_columns[str(attr_type)]
        fst, lst = columns[0], columns[-1]+1
        data = data.iloc[:, fst:lst]
    
    return data

# %%
# %cache coarse_vgg16_oversampled = train('VGG16',model_id='coarse5', freeze_layers_ratio=0.60)
# %cache coarse_vgg16_oversampled_test_res = evaluate('VGG16', model_id = 'coarse5')
build_result_df([(coarse_vgg16_oversampled_test_res[1], 'VGG16 alt. D')], k=5)
# Out:
# Loading cached value for variable 'coarse_vgg16_oversampled'. Time since caching: 12:17:56.561902
# Loading cached value for variable 'coarse_vgg16_oversampled_test_res'. Time since caching: 12:09:38.822364
#               recall.micro  precision.micro  f1.micro  recall.macro  \
# VGG16 alt. D          0.00             0.00      0.00          0.01
#
#               precision.macro  f1.macro
# VGG16 alt. D             0.00      0.00

# %% [markdown]
# # 3. Conclusiones

# %% [markdown]
# La conclusión que se obtiene con los resultados mostrados en el apartado anterior es que la clasificación de atributos no es abordable con redes convolucionales simples cuando el número de atributos es alto. El valor de la métrica *top-k recall* obtenido (0.01) es inferior a los modelos considerados estado del arte que emplean este mismo conjunto de datos, que obtienen valores superiores a 0.3.
#
# Estos modelos son más complejos y suelen realizar la predicción en varios pasos, donde cada uno de estos pasos se basa en la predicción realizada en los pasos anteriores. Por ejemplo, tanto *FashionNet* como el modelo descrito en [https://github.com/fdjingyuan/Deep-Fashion-Analysis-ECCV2018](https://github.com/fdjingyuan/Deep-Fashion-Analysis-ECCV2018)
# realizan la predicción en tres fases:
# 1. Predicción de landmarks
# 2. Predicción de la categoría de la prenda
# 3. Predicción de los atributos.
#
# donde, para cada una de las predicciónes, se emplea la información generada en el paso anterior tal y como muestra la siguiente imagen, extraída del repositorio anteriormente mencionado:
#
# ![title](../img/network.png)
#
# Dado el pobre rendimiento obtenido con la versión con un único clasificador se ha omitido realizar las pruebas con la versión con un clasificador por tipo de atributo puesto que se asume que los resultados obtenidos serán similares.
